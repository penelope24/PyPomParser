# %%
import re

# %%
text1 = ""
text2 = ""
text3 = ""
text4 = ""

with open("/Users/fy/Downloads/spring-security-oauth/pom.xml", "r") as f:
    # text1 = f.read()
    lines1 = f.readlines()

with open("/Users/fy/Downloads/spring-security-oauth/spring-security-oauth/pom.xml", "r") as f:
    text2 = f.read()

with open("/Users/fy/Downloads/spring-security-oauth/spring-security-oauth2/pom.xml", "r") as f:
    text3 = f.read()

# %%
for line in lines1:
    print(line)
# Out:
# <project xmlns="http://maven.apache.org/POM/4.0.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://maven.apache.org/POM/4.0.0 https://maven.apache.org/maven-v4_0_0.xsd">
#
#   <modelVersion>4.0.0</modelVersion>
#
#   <groupId>org.springframework.security.oauth</groupId>
#
#   <artifactId>spring-security-oauth-parent</artifactId>
#
#   <name>OAuth for Spring Security</name>
#
#   <description>Parent Project for OAuth Support for Spring Security</description>
#
#   <packaging>pom</packaging>
#
#   <version>2.5.3.BUILD-SNAPSHOT</version>
#
#   <url>https://docs.spring.io/spring-security/oauth</url>
#
#
#
#   <modules>
#
#     <module>spring-security-oauth</module>
#
#     <module>spring-security-oauth2</module>
#
#     <module>tests</module>
#
#   <module>samples</module>
#
#     <!--module>spring-security-jwt</module-->
#
#   </modules>
#
#
#
#   <properties>
#
#     <project.build.sourceEncoding>UTF-8</project.build.sourceEncoding>
#
# ...

# %%
from data.TreeNode import TreeNode

root = TreeNode()
